# %%
from openpyxl import Workbook

# Create a new Excel workbook
wb = Workbook()

# Select the active worksheet
ws = wb.active

# Example print statements
print_statements = [
    "Hello, world!",
    "This is a test print statement.",
    "Exporting print statements to Excel."
]

# Write the print statements to Excel
for row, statement in enumerate(print_statements, start=1):
    tim = ws.cell(row=row, column=1, value=statement)

# Save the workbook
print(enumerate(print_statements, start=1))

# %%
import pandas as pd
import os
import glob
from openpyxl import Workbook

# %%
pip install pyxlsb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path = '/Users/emmanuel.olatunbosun/Downloads/wetransfer_team-apt-2022-contiue-xlsb_2024-01-31_2021'
df = glob.glob(path + "/team*.xlsb")

# %%
print(df)
# Out:
# ['/Users/emmanuel.olatunbosun/Downloads/wetransfer_team-apt-2022-contiue-xlsb_2024-01-31_2021/team apt 2023.xlsb', '/Users/emmanuel.olatunbosun/Downloads/wetransfer_team-apt-2022-contiue-xlsb_2024-01-31_2021/team Apt 2022 contiue .xlsb', '/Users/emmanuel.olatunbosun/Downloads/wetransfer_team-apt-2022-contiue-xlsb_2024-01-31_2021/teamapt new.xlsb']

# %%
df2 = []
for file in df:
    combine_sheets = pd.read_excel(file, sheet_name = None, header = None, engine= 'pyxlsb')
    df2.append(combine_sheets)

# %%
print(df2)
# Out:
# [{'November - december 2023':                                     0  \
# 0       MNFY|63|20231030235953|002383
# 1       MNFY|78|20231031000048|160393
# 2       MNFY|78|20231031000109|160398
# 3       MNFY|81|20231031000112|159191
# 4       MNFY|78|20231031000136|160406
# ...                               ...
# 245134  MNFY|00|20231228235519|223825
# 245135  MNFY|15|20231228235522|222587
# 245136  MNFY|23|20231228235609|223523
# 245137  MNFY|15|20231228235552|222591
# 245138  MNFY|95|20231228235812|223200
#
#                                                     1        2             3  \
# 0        ZIB|API|MX14239|31-10-2023|1209507919|167563  MX14239  135472003081
# 1        FBN|API|MX14239|31-10-2023|1209508208|757050  MX14239  812420004867
# 2        ABP|API|MX14239|31-10-2023|1209508263|814643  MX14239  317755004871
# 3        FBP|API|MX14239|31-10-2023|1209508311|724453  MX14239  966495003621
# 4        ABP|API|MX14239|31-10-2023|1209508348|481325  MX14239   87316003673
# ...

# %%
df2['August'].items()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df2['August'].items()
#
# TypeError: list indices must be integers or slices, not str

# %%
dataframe = []
for file_sheets in df2:
    for sheet_name, sheet_data in file_sheets.items():
        dataframe.append(pd.DataFrame(sheet_data))

# %%
df3 = pd.concat(dataframe, ignore_index=True)

# %%
df3.head()
# Out:
#                                0  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                               1        2             3     4  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563  MX14239  135472003081  3081
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050  MX14239  812420004867  4867
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643  MX14239  317755004871  4871
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453  MX14239  966495003621  3621
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325  MX14239   87316003673  3673
#
#           5         6             7             8
# 0     438.6    435.05  45230.000401  45231.000239
# 1   11000.0   10910.9  45230.000981  45231.000239
# 2   15503.4  15377.82   45230.00111  45231.000239
# 3  155000.0  153744.5  45230.001225  45231.000239
# ...

# %%
df3[6] = pd.to_numeric(df3[6], errors="coerce")

# %%
df3.dropna(subset=[6], inplace=True)

# %%
df3.head()
# Out:
#                                0  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                               1        2             3     4  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563  MX14239  135472003081  3081
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050  MX14239  812420004867  4867
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643  MX14239  317755004871  4871
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453  MX14239  966495003621  3621
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325  MX14239   87316003673  3673
#
#           5          6                             7  \
# 0     438.6     435.05 2023-10-31 00:00:34.650028800
# 1   11000.0   10910.90 2023-10-31 00:01:24.786998400
# 2   15503.4   15377.82 2023-10-31 00:01:35.930006400
# 3  155000.0  153744.50 2023-10-31 00:01:45.799996800
# ...

# %%
df3[7]= pd.to_datetime(pd.to_numeric(df3[7],errors='coerce'),errors='coerce',origin='1899-12-30',unit='D')
df3[8]= pd.to_datetime(pd.to_numeric(df3[8],errors='coerce'),errors='coerce',origin='1899-12-30',unit='D')

# %%
wb = Workbook()
ws = wb.active

        
for group, state in df3.groupby(df3[8]):
    amount_by_date = state[6].sum()
    ws.append([group, amount_by_date])

wb.save("output1.xlsx")

# %%
test2 = pd.to_datetime(pd.to_numeric(df3[8],errors='coerce'),errors='coerce',origin='1899-12-30',unit='D')

# %%
test2.head()
# Out:
# 0   2023-11-01 00:00:20.659968
# 1   2023-11-01 00:00:20.659968
# 2   2023-11-01 00:00:20.659968
# 3   2023-11-01 00:00:20.659968
# 4   2023-11-01 00:00:20.659968
# Name: 8, dtype: datetime64[ns]

# %%
destination_path ='/Users/emmanuel.olatunbosun/Downloads/wetransfer_team-apt-2022-contiue-xlsb_2024-01-31_2021/2nd_2021.csv'
df3.to_csv(path_or_buf = destination_path, sep=',', index = False)

# %%
sort = df3.sort_values(by=[2])
sort.tail()
# Out:
#                         0                              1              2  \
# 19  transaction_reference  channel_transaction_reference  merchant_code
# 10  transaction_reference  channel_transaction_reference  merchant_code
# 20  transaction_reference  channel_transaction_reference  merchant_code
# 18  transaction_reference  channel_transaction_reference  merchant_code
# 21  transaction_reference  channel_transaction_reference  merchant_code
#
#                              3     4       5                  6  \
# 19  retrieval_reference_number  stan  amount  settlement_amount
# 10  retrieval_reference_number  stan  amount  settlement_amount
# 20  retrieval_reference_number  stan  amount  settlement_amount
# 18  retrieval_reference_number  stan  amount  settlement_amount
# 21  retrieval_reference_number  stan  amount  settlement_amount
#
#                   7                8
# 19  date_of_payment  settlement_date
# 10  date_of_payment  settlement_date
# ...

# %%
new_time = pd.to_datetime(sort[7])
new_time.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/tslibs/parsing.pyx:318, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~/anaconda3/lib/python3.10/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/dateutil/parser/_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#
# ParserError: Unknown string format: date_of_payment
#
# ...

# %%
df10 = pd.read_excel('/Users/emmanuel.olatunbosun/Downloads/wetransfer_team-apt-2022-contiue-xlsb_2024-01-31_2021/team apt 2021.xlsx', sheet_name = None, header = None)
print(df10)
# Out:
# {'2019 - 2020':                                     0  \
# 0               transaction_reference
# 1          MNFY|20191108190432|000011
# 2          MNFY|20191108191034|000012
# 3          MNFY|20191112105742|000058
# 4          MNFY|20191112144302|000063
# ...                               ...
# 272885  MNFY|84|20201230235213|009889
# 272886  MNFY|00|20201230235139|006730
# 272887  MNFY|00|20201230235307|006741
# 272888  MNFY|84|20201230235559|009902
# 272889  MNFY|75|20201230235743|006449
#
#                                                    1              2  \
# 0                      channel_transaction_reference  merchant_code
# 1       IBTC|API|MX14239|08-11-2019|315316987|128574        MX14239
# 2        FBN|API|MX14239|08-11-2019|315319980|847984        MX14239
# 3        UBA|API|MX14239|12-11-2019|316970095|924953        MX14239
# 4        ABP|API|MX14239|12-11-2019|317074166|921277        MX14239
# ...                                              ...            ...
# ...

# %%
dataframe2 = []
for sheet_name, sheet_data in df10.items():
    dataframe2.append(sheet_data)

combined_dataframe = pd.concat(dataframe2, ignore_index=True)

# %%
combined_dataframe[6] = pd.to_numeric(combined_dataframe[6], errors="coerce")

# %%
combined_dataframe.dropna(subset=[6], inplace=True)

# %%
combined_dataframe[8] = pd.to_datetime(combined_dataframe[8])

# %%
combined_dataframe[8].info
# Out:
# <bound method Series.info of 1         2019-11-12 00:00:35
# 2         2019-11-12 00:00:35
# 3         2019-11-13 00:00:14
# 4         2019-11-13 00:00:14
# 5         2019-11-13 00:00:14
#                   ...
# 1855223   2022-01-31 00:00:08
# 1855224   2022-01-31 00:00:08
# 1855225   2022-01-31 00:00:08
# 1855226   2022-01-31 00:00:08
# 1855227   2022-01-31 00:00:08
# Name: 8, Length: 1855224, dtype: datetime64[ns]>

# %%
combined_dataframe[7] = pd.to_datetime(combined_dataframe[7])

# %%
combined_dataframe.head()
# Out:
#                             0                                             1  \
# 1  MNFY|20191108190432|000011  IBTC|API|MX14239|08-11-2019|315316987|128574
# 2  MNFY|20191108191034|000012   FBN|API|MX14239|08-11-2019|315319980|847984
# 3  MNFY|20191112105742|000058   UBA|API|MX14239|12-11-2019|316970095|924953
# 4  MNFY|20191112144302|000063   ABP|API|MX14239|12-11-2019|317074166|921277
# 5  MNFY|20191112163100|000080  IBTC|API|MX14239|12-11-2019|317168017|598453
#
#          2             3       4        5        6                   7  \
# 1  MX14239  001653299828  507436    50.00    49.63 2019-11-08 20:05:23
# 2  MX14239  001653342435  509818   200.00   198.50 2019-11-08 20:11:28
# 3  MX14239  001684891879  078954  1100.00  1091.75 2019-11-12 12:15:04
# 4  MX14239  001686522501  100332    50.00    49.63 2019-11-12 15:46:42
# 5  MX14239  001687798232  116591    50.00    49.63 2019-11-12 18:21:52
#
#                          8
# 1  2019-11-12 00:00:35.000
# ...

# %%
destination_path2 ='/Users/emmanuel.olatunbosun/Downloads/wetransfer_team-apt-2022-contiue-xlsb_2024-01-31_2021/concat.csv'

# %%
combined_dataframe.to_csv(destination_path2, index=False)

# %%
df_concat = pd.concat([df3,combined_dataframe])

# %%
df_merged1 = pd.merge(df3,combined_dataframe)

# %%
df_concat.head()
# Out:
#                                0  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                               1        2             3     4  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563  MX14239  135472003081  3081
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050  MX14239  812420004867  4867
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643  MX14239  317755004871  4871
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453  MX14239  966495003621  3621
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325  MX14239   87316003673  3673
#
#           5          6                             7  \
# 0     438.6     435.05 2023-10-31 00:00:34.650028800
# 1   11000.0   10910.90 2023-10-31 00:01:24.786998400
# 2   15503.4   15377.82 2023-10-31 00:01:35.930006400
# 3  155000.0  153744.50 2023-10-31 00:01:45.799996800
# ...

# %%
df_concat.to_csv(destination_path2, index=False)

# %%
wb = Workbook()
ws = wb.active

        
for group, state in df_concat.groupby(df_concat[8]):
    amount_by_date = state[6].sum()
    ws.append([group, amount_by_date])

wb.save("correct sum.xlsx")

# %%
print(len(df_concat.axes[0]))
# Out:
# 7724779

# %%
df_concat[6].sum()
# Out:
# 42059146094.36002

# %%
split = pd.read_csv('/Users/emmanuel.olatunbosun/Downloads/concat.csv')

# %%
split.head()
# Out:
#                                0  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                               1        2             3  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563  MX14239  1.354720e+11
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050  MX14239  8.124200e+11
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643  MX14239  3.177550e+11
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453  MX14239  9.664950e+11
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325  MX14239  8.731600e+10
#
#         4          5          6                              7  \
# 0  3081.0     438.60     435.05  2023-10-31 00:00:34.650028800
# 1  4867.0   11000.00   10910.90  2023-10-31 00:01:24.786998400
# 2  4871.0   15503.40   15377.82  2023-10-31 00:01:35.930006400
# 3  3621.0  155000.00  153744.50  2023-10-31 00:01:45.799996800
# ...

# %%
split.columns = ['Monnify_ref','Channel_ref','Merchant_code','RRN','Stan','Transaction_amount','Settlement_amount','Transaction_date','Settlement_date']

# %%
split.head()
# Out:
#                      Monnify_ref  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                     Channel_ref Merchant_code           RRN  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563       MX14239  1.354720e+11
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050       MX14239  8.124200e+11
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643       MX14239  3.177550e+11
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453       MX14239  9.664950e+11
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325       MX14239  8.731600e+10
#
#      Stan  Transaction_amount  Settlement_amount  \
# 0  3081.0              438.60             435.05
# 1  4867.0            11000.00           10910.90
# 2  4871.0            15503.40           15377.82
# 3  3621.0           155000.00          153744.50
# 4  3673.0              558.25             553.73
#
# ...

# %%
from IPython.core.display import display,HTML
display(HTML('<style>.container{width:100%}</style>'))
# Out:
# /var/folders/c_/286x5j9d4yz8rq8sbmm94_z00000gr/T/ipykernel_42644/777987360.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display,HTML
# <style>.container{width:100%}</style>

# %%
sample = split.head()

# %%
sample.to_csv('/Users/emmanuel.olatunbosun/Downloads/check.csv')

# %%
convert_dict = {'RRN': str,
                'Stan': str
                }

# %%
split_1 = split.astype(convert_dict)

# %%
split_1.head()
# Out:
#                      Monnify_ref  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                     Channel_ref Merchant_code             RRN  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563       MX14239  135472003081.0
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050       MX14239  812420004867.0
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643       MX14239  317755004871.0
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453       MX14239  966495003621.0
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325       MX14239   87316003673.0
#
#      Stan  Transaction_amount  Settlement_amount  \
# 0  3081.0              438.60             435.05
# 1  4867.0            11000.00           10910.90
# 2  4871.0            15503.40           15377.82
# 3  3621.0           155000.00          153744.50
# ...

# %%
split_2 = split_1.copy()

# %%
split_1['RRN']= split_1['RRN'].str.split(pat='.').str[0]

# %%
split_1['Stan']= split_1['Stan'].str.split(pat='.').str[0]

# %%
split_1.head()
# Out:
#                      Monnify_ref  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                     Channel_ref Merchant_code           RRN  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563       MX14239  135472003081
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050       MX14239  812420004867
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643       MX14239  317755004871
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453       MX14239  966495003621
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325       MX14239   87316003673
#
#    Stan  Transaction_amount  Settlement_amount               Transaction_date  \
# 0  3081              438.60             435.05  2023-10-31 00:00:34.650028800
# 1  4867            11000.00           10910.90  2023-10-31 00:01:24.786998400
# ...

# %%
split_1['Settlement_date'] = pd.to_datetime(split_1['Settlement_date']).dt.date

# %%
split_1.head()
# Out:
#                      Monnify_ref  \
# 0  MNFY|63|20231030235953|002383
# 1  MNFY|78|20231031000048|160393
# 2  MNFY|78|20231031000109|160398
# 3  MNFY|81|20231031000112|159191
# 4  MNFY|78|20231031000136|160406
#
#                                     Channel_ref Merchant_code           RRN  \
# 0  ZIB|API|MX14239|31-10-2023|1209507919|167563       MX14239  135472003081
# 1  FBN|API|MX14239|31-10-2023|1209508208|757050       MX14239  812420004867
# 2  ABP|API|MX14239|31-10-2023|1209508263|814643       MX14239  317755004871
# 3  FBP|API|MX14239|31-10-2023|1209508311|724453       MX14239  966495003621
# 4  ABP|API|MX14239|31-10-2023|1209508348|481325       MX14239   87316003673
#
#    Stan  Transaction_amount  Settlement_amount               Transaction_date  \
# 0  3081              438.60             435.05  2023-10-31 00:00:34.650028800
# 1  4867            11000.00           10910.90  2023-10-31 00:01:24.786998400
# ...

# %%
for group, state in split_1.groupby(split_1['Settlement_date']):
    output_path = os.path.join('/Users/emmanuel.olatunbosun/Downloads/4_divine', f'{group}.xlsx')
    state.to_excel(output_path, index= False)
